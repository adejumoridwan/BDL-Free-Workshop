# %% [markdown]
# # Analyzing Motorcyle Sales Data

# %% [markdown]
# ## Data Munging

# %% [markdown]
# **Importing libraries**

# %%
#allows plots to be displayed in notebooks and not on a new window
# %matplotlib inline 
import numpy as np
import pandas as pd

# %% [markdown]
# **Reading the motorcycles sales data**

# %%
sales = pd.read_csv("sales.csv")

# %%
sales
# Out:
#            date warehouse client_type           product_line  quantity  \
# 0      1/6/2021   Central      Retail          Miscellaneous         8
# 1      1/6/2021     North      Retail        Breaking system         9
# 2      1/6/2021     North      Retail  Suspension & traction         8
# 3      1/6/2021     North   Wholesale           Frame & body        16
# 4      1/6/2021   Central      Retail                 Engine         2
# ..          ...       ...         ...                    ...       ...
# 995  28/08/2021   Central      Retail      Electrical system         9
# 996  28/08/2021      West   Wholesale        Breaking system        32
# 997  28/08/2021      West   Wholesale      Electrical system        12
# 998  28/08/2021     North      Retail           Frame & body         5
# 999  28/08/2021     North   Wholesale      Electrical system        20
#
#      unit_price   total      payment
# 0         16.85  134.83  Credit card
# 1         19.29  173.61         Cash
# 2         32.93  263.45  Credit card
# 3         37.84  605.44     Transfer
# 4         60.48  120.96  Credit card
# ..          ...     ...          ...
# 995       32.87  295.83  Credit card
# 996       10.03  320.96     Transfer
# 997       32.80  393.64     Transfer
# 998       48.25  241.23         Cash
# 999       27.41  548.13     Transfer
#
# [1000 rows x 8 columns]

# %%
sales  = pd.read_csv("sales.csv")

# %% [markdown]
# **Checking for the first 5 rows of the data**

# %%
sales.tail()
# Out:
#            date warehouse client_type           product_line  quantity  \
# 980  26/08/2021      West      Retail        Breaking system         4
# 981  27/08/2021   Central   Wholesale                 Engine        20
# 982  27/08/2021   Central      Retail      Electrical system         7
# 983  27/08/2021     North   Wholesale  Suspension & traction        12
# 984  27/08/2021   Central      Retail      Electrical system        10
# 985  27/08/2021     North      Retail      Electrical system        10
# 986  27/08/2021      West      Retail      Electrical system         4
# 987  27/08/2021   Central      Retail                 Engine         5
# 988  27/08/2021   Central      Retail                 Engine        10
# 989  28/08/2021     North      Retail           Frame & body         7
# 990  28/08/2021      West   Wholesale          Miscellaneous        32
# 991  28/08/2021   Central   Wholesale          Miscellaneous         8
# 992  28/08/2021   Central   Wholesale      Electrical system        32
# 993  28/08/2021      West      Retail      Electrical system         6
# 994  28/08/2021     North      Retail  Suspension & traction         6
# 995  28/08/2021   Central      Retail      Electrical system         9
# 996  28/08/2021      West   Wholesale        Breaking system        32
# 997  28/08/2021      West   Wholesale      Electrical system        12
# 998  28/08/2021     North      Retail           Frame & body         5
# 999  28/08/2021     North   Wholesale      Electrical system        20
#
#      unit_price    total      payment
# 980       16.63    66.53         Cash
# 981       60.22  1204.30     Transfer
# 982       28.63   200.40         Cash
# 983       37.07   444.84     Transfer
# 984       30.39   303.90         Cash
# 985       28.56   285.63  Credit card
# 986       21.47    85.89  Credit card
# 987       59.14   295.72  Credit card
# 988       64.64   646.45  Credit card
# 989       40.04   280.27  Credit card
# 990       25.42   813.44     Transfer
# 991       28.90   231.20     Transfer
# 992       28.76   920.37     Transfer
# 993       28.37   170.21  Credit card
# 994       30.74   184.42  Credit card
# 995       32.87   295.83  Credit card
# 996       10.03   320.96     Transfer
# 997       32.80   393.64     Transfer
# 998       48.25   241.23         Cash
# 999       27.41   548.13     Transfer

# %% [markdown]
# **Checking for the data types of the data**

# %%
sales.dtypes
# Out:
# date             object
# warehouse        object
# client_type      object
# product_line     object
# quantity          int64
# unit_price      float64
# total           float64
# payment          object
# dtype: object

# %% [markdown]
# **Determine the number of rows and columns in the dataset**

# %%
sales.shape
# Out:
# (1000, 8)

# %%
sales.shape

# %% [markdown]
# **Get column names in the dataset**

# %%
column_names = sales.columns
column_names
# Out:
# Index(['date', 'warehouse', 'client_type', 'product_line', 'quantity',
#        'unit_price', 'total', 'payment'],
#       dtype='object')

# %%
sales["warehouse"][0:5]
# Out:
# 0    Central
# 1      North
# 2      North
# 3      North
# 4    Central
# Name: warehouse, dtype: object

# %% [markdown]
# **Get the first five rows of the column client type by name**

# %%
sales["client_type"][0:6]

# %% [markdown]
# **Get the first five rows of the column warehouse by name**

# %%
sales["warehouse"][1:5]

# %% [markdown]
# **Index the columns of the first 10 rows and first 3 columns**

# %%
subset = sales.iloc[0:9,:]
sales
# Out:
#            date warehouse client_type           product_line  quantity  \
# 0      1/6/2021   Central      Retail          Miscellaneous         8
# 1      1/6/2021     North      Retail        Breaking system         9
# 2      1/6/2021     North      Retail  Suspension & traction         8
# 3      1/6/2021     North   Wholesale           Frame & body        16
# 4      1/6/2021   Central      Retail                 Engine         2
# ..          ...       ...         ...                    ...       ...
# 995  28/08/2021   Central      Retail      Electrical system         9
# 996  28/08/2021      West   Wholesale        Breaking system        32
# 997  28/08/2021      West   Wholesale      Electrical system        12
# 998  28/08/2021     North      Retail           Frame & body         5
# 999  28/08/2021     North   Wholesale      Electrical system        20
#
#      unit_price   total      payment
# 0         16.85  134.83  Credit card
# 1         19.29  173.61         Cash
# 2         32.93  263.45  Credit card
# 3         37.84  605.44     Transfer
# 4         60.48  120.96  Credit card
# ..          ...     ...          ...
# 995       32.87  295.83  Credit card
# 996       10.03  320.96     Transfer
# 997       32.80  393.64     Transfer
# 998       48.25  241.23         Cash
# 999       27.41  548.13     Transfer
#
# [1000 rows x 8 columns]

# %%
sales.loc[0:4,["date","warehouse","client_type"]]
# Out:
#        date warehouse client_type
# 0  1/6/2021   Central      Retail
# 1  1/6/2021     North      Retail
# 2  1/6/2021     North      Retail
# 3  1/6/2021     North   Wholesale
# 4  1/6/2021   Central      Retail

# %%
sales.loc[:,["client_type","warehouse"]]

# %% [markdown]
# **Order the data by a specific column**

# %%
sales.sort_values("unit_price", ascending=False)
# Out:
#            date warehouse client_type     product_line  quantity  unit_price  \
# 627  27/07/2021   Central      Retail           Engine         6       66.62
# 212  21/06/2021      West      Retail           Engine         6       66.53
# 402    6/7/2021      West      Retail           Engine         3       66.37
# 840  13/08/2021     North      Retail           Engine         2       66.10
# 292  27/06/2021   Central      Retail           Engine         4       66.03
# ..          ...       ...         ...              ...       ...         ...
# 65     8/6/2021      West      Retail  Breaking system         1       10.46
# 576  22/07/2021      West      Retail  Breaking system         1       10.42
# 814   11/8/2021      West      Retail  Breaking system         8       10.36
# 274  26/06/2021     North      Retail  Breaking system         1       10.35
# 996  28/08/2021      West   Wholesale  Breaking system        32       10.03
#
#       total      payment
# 627  399.71  Credit card
# 212  399.19         Cash
# 402  199.10  Credit card
# 840  132.19  Credit card
# 292  264.11  Credit card
# ..      ...          ...
# 65    10.46  Credit card
# 576   10.42  Credit card
# 814   82.92  Credit card
# 274   10.35  Credit card
# 996  320.96     Transfer
#
# [1000 rows x 8 columns]

# %%
sales.sort_values("total", ascending=True)

# %% [markdown]
# **Sort data by a column and obtain a cross-section of the data**

# %%
sorted_data = sales.sort_values(["quantity"], ascending=True)
sorted_data

# %%
sorted_data = sales.sort_values(["total"], ascending=False)
sorted_data.iloc[:,:].head(5)

# %% [markdown]
# **Obtain Value Counts of all products under product line**

# %%
sales["payment"].value_counts()
# Out:
# Credit card    659
# Transfer       225
# Cash           116
# Name: payment, dtype: int64

# %%
sales["product_line"].value_counts()

# %%
sales["warehouse"].value_counts(), sales["product_line"].value_counts(), sales["client_type"].value_counts()

# %% [markdown]
# **Get the unique value of a column by names**

# %%
sales.head()
# Out:
#        date warehouse client_type           product_line  quantity  \
# 0  1/6/2021   Central      Retail          Miscellaneous         8
# 1  1/6/2021     North      Retail        Breaking system         9
# 2  1/6/2021     North      Retail  Suspension & traction         8
# 3  1/6/2021     North   Wholesale           Frame & body        16
# 4  1/6/2021   Central      Retail                 Engine         2
#
#    unit_price   total      payment
# 0       16.85  134.83  Credit card
# 1       19.29  173.61         Cash
# 2       32.93  263.45  Credit card
# 3       37.84  605.44     Transfer
# 4       60.48  120.96  Credit card

# %%
len(sales["product_line"].unique())
# Out:
# 6

# %%
sales["product_line"].unique()

# %% [markdown]
# **Get the unique count of the unique values of a column**

# %%
len(sales["product_line"].unique())

# %% [markdown]
# **Index into a column and get the first four rows**

# %%
sales.loc[0:10,["total","payment"]]

# %% [markdown]
# ## Data Aggregration

# %% [markdown]
# **Describe data**

# %%
sales.head()
# Out:
#        date warehouse client_type           product_line  quantity  \
# 0  1/6/2021   Central      Retail          Miscellaneous         8
# 1  1/6/2021     North      Retail        Breaking system         9
# 2  1/6/2021     North      Retail  Suspension & traction         8
# 3  1/6/2021     North   Wholesale           Frame & body        16
# 4  1/6/2021   Central      Retail                 Engine         2
#
#    unit_price   total      payment
# 0       16.85  134.83  Credit card
# 1       19.29  173.61         Cash
# 2       32.93  263.45  Credit card
# 3       37.84  605.44     Transfer
# 4       60.48  120.96  Credit card

# %%
sales.describe()
# Out:
#           quantity   unit_price        total
# count  1000.000000  1000.000000  1000.000000
# mean      9.395000    30.322040   289.113000
# std       9.659207    12.256488   345.227596
# min       1.000000    10.030000    10.350000
# 25%       4.000000    21.085000    93.687500
# 50%       6.500000    28.570000   178.360000
# 75%      10.000000    37.917500   321.690000
# max      40.000000    66.620000  2546.330000

# %%
sales.describe()

# %%
pd.crosstab(sales["client_type"], sales["payment"])
# Out:
# payment      Cash  Credit card  Transfer
# client_type
# Retail        116          659         0
# Wholesale       0            0       225

# %%
pd.crosstab(sales["product_line"], sales["client_type"])
# Out:
# client_type            Retail  Wholesale
# product_line
# Breaking system           175         55
# Electrical system         155         38
# Engine                     48         13
# Frame & body              128         38
# Miscellaneous              92         30
# Suspension & traction     177         51

# %%
pd.crosstab(sales["warehouse"],sales["client_type"]),pd.crosstab(sales["product_line"],sales["client_type"])

# %%
pd.crosstab(sales["warehouse"],sales["client_type"])

# %% [markdown]
# **Return the subset of a data**

# %%
sales[(sales["client_type"] == "Wholesale") & (sales["warehouse"]=="Central")]
# Out:
#            date warehouse client_type           product_line  quantity  \
# 42     5/6/2021   Central   Wholesale        Breaking system         4
# 48     6/6/2021   Central   Wholesale                 Engine        36
# 55     7/6/2021   Central   Wholesale           Frame & body         4
# 60     7/6/2021   Central   Wholesale  Suspension & traction        40
# 67     8/6/2021   Central   Wholesale           Frame & body         8
# ..          ...       ...         ...                    ...       ...
# 964  25/08/2021   Central   Wholesale      Electrical system         8
# 968  25/08/2021   Central   Wholesale        Breaking system        12
# 981  27/08/2021   Central   Wholesale                 Engine        20
# 991  28/08/2021   Central   Wholesale          Miscellaneous         8
# 992  28/08/2021   Central   Wholesale      Electrical system        32
#
#      unit_price    total   payment
# 42        13.65    54.60  Transfer
# 48        63.41  2282.82  Transfer
# 55        44.69   178.75  Transfer
# 60        28.64  1145.47  Transfer
# 67        44.14   353.11  Transfer
# ..          ...      ...       ...
# 964       25.95   207.56  Transfer
# 968       13.19   158.30  Transfer
# 981       60.22  1204.30  Transfer
# 991       28.90   231.20  Transfer
# 992       28.76   920.37  Transfer
#
# [109 rows x 8 columns]

# %%
sales[(sales["total"] > 1000) & (sales["warehouse"] == "Central")].head()
# Out:
#            date warehouse client_type           product_line  quantity  \
# 48     6/6/2021   Central   Wholesale                 Engine        36
# 60     7/6/2021   Central   Wholesale  Suspension & traction        40
# 141  15/06/2021   Central   Wholesale                 Engine        28
# 146  15/06/2021   Central   Wholesale           Frame & body        24
# 176  18/06/2021   Central   Wholesale           Frame & body        36
#
#      unit_price    total   payment
# 48        63.41  2282.82  Transfer
# 60        28.64  1145.47  Transfer
# 141       63.54  1779.07  Transfer
# 146       48.95  1174.88  Transfer
# 176       48.44  1743.78  Transfer

# %%
subset = sales[(sales["total"] > 1000) & (sales["warehouse"] == "Central")].head()
subset

# %% [markdown]
# **Obtaining the average sales made in each warehouse and payment**

# %%
grouped_client = sales.groupby(["client_type"]).sum("total")

# %%
sales.groupby(["product_line","payment","client_type"]).sum("total")
# Out:
#                                                quantity  unit_price     total
# product_line          payment     client_type
# Breaking system       Cash        Retail            130      425.35   2241.52
#                       Credit card Retail            732     2654.27  12977.73
#                       Transfer    Wholesale        1268     1000.70  23130.90
# Electrical system     Cash        Retail            117      616.64   2917.44
#                       Credit card Retail            745     3335.80  18940.86
#                       Transfer    Wholesale         836      985.49  21754.41
# Engine                Cash        Retail             43      366.20   2599.72
#                       Credit card Retail            236     2507.38  14109.61
#                       Transfer    Wholesale         348      792.02  21236.05
# Frame & body          Cash        Retail            112      825.90   4823.27
#                       Credit card Retail            575     4653.50  24723.57
#                       Transfer    Wholesale         932     1630.75  39477.89
# Miscellaneous         Cash        Retail             99      409.68   2198.45
#                       Credit card Retail            409     1663.61   9219.56
#                       Transfer    Wholesale         668      709.62  15747.81
# Suspension & traction Cash        Retail            126      836.21   4418.70
#                       Credit card Retail            891     5177.77  30300.24
#                       Transfer    Wholesale        1128     1731.15  38295.27

# %%
sales.groupby(["client_type","payment"]).mean("total").sort_values(["total"], ascending = False)

# %% [markdown]
# ## Visualization

# %%
sales.product_line.value_counts().plot(kind = "pie")
# Out:
# <AxesSubplot:ylabel='product_line'>

# %% [markdown]
# **Number of sales made by client type**

# %%
sales.client_type.value_counts().plot(kind = "bar")

# %% [markdown]
# **Number of Sales made from each store**

# %%
sales.warehouse.value_counts().plot(kind = "pie")

# %%
sales.groupby("product_line")["unit_price"].agg(np.mean).plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='product_line'>

# %% [markdown]
# **Total sales made from each payment method**

# %%
sales.groupby("warehouse")["total"].agg(np.sum).plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='warehouse'>

# %%
sales.groupby("warehouse")["total"].agg(np.sum).plot(kind = "bar")
